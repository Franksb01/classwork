# %% [markdown]
# # Data Types
#
# ## Simple Data Types
#
# -string(str)
# -Integer(int)
# -Float(float)
# -boolean (bool)
#
# ## Complex Data Types
#
# - list(list)
# - tuple(tuple)
# - dictionary(dict)
# - set(set)
#
# ## Data
#
# - Data and Dataline

# %%
my_string = "This is my string"

# %%
print(my_string)
# Out:
# This is my string

# %%
my_string = "This is my new string"
print(my_string)
# Out:
# This is my new string

# %%
print(my_string.upper())
print(my_string)
# Out:
# THIS IS MY NEW STRING
# This is my new string

# %%
# index of collections
print(len(my_string))
my_string[0]
# Out:
# 21
# 'T'

# %%
my_string[-3]
# Out:
# 'i'

# %%
print(my_string)
ending = "this is the ending"
print(ending)
my_string = my_string + ending
print(my_string)
# Out:
# This is my new stringThis is the endThis is the endThis is the endThis is the end
# this is the ending
# This is my new stringThis is the endThis is the endThis is the endThis is the endthis is the ending

# %%
my_string: str = "it will work withour the hint"

# %%
# Intergers
a:int = 25
b:int = 5

print("addition: ", a + b) #addition
print(f"division: {a/b}") #division
print(f"multiplication: {a*b}") #multiplication
print(f"subtraction: {a - b}") #subtraction
print(f"exponentiation: {a**b}") #exponentiation
print(f"floor division: {a//b}") #floor division
print(f"modulus: {a%b}") #modulus
# Out:
# addition:  30
# division: 5.0
# multiplication: 125
# subtraction: 20
# exponentiation: 9765625
# floor division: 5
# modulus: 0

# %%
a= str(a)
b= float(b)

print(f"new type a and b: {a.zfill(3), b}")
print(int(3.99999))
# Out:
# new type a and b: ('025', 5.0)
# 3

# %%
#boolean
x:bool = True
print(f"x: {x}")
print(f"b as bool: {bool(b)}")
print(f"o as bool: {bool(0)}")
print(f"empty string as bool: {bool('')}")
print (f"a string as bool: {bool(a)}")
# Out:
# x: True
# b as bool: True
# o as bool: False
# empty string as bool: False
# a string as bool: True

# %%
# List
# Ordered
# Mutable
# allows repeated values

my_list = [1, 2, "3", False, [1,2,3]]

# %%
my_list = [-1]
list2 = list((1,2,3))
print(list2)
print(list2.pop())
print(list2)
list2.pop()
print(list2)
# Out:
# [1, 2, 3]
# 3
# [1, 2]
# [1]

# %%
l1 = []
l1.append(1)
print(l1)
l1.append(2)
print(l1)
l1.pop()
print(l1)
# Out:
# [1]
# [1, 2]
# [1]

# %%
l2 =[1,2,3]
l2.pop(0)
# Out:
# 1
